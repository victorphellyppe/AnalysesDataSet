# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("csv/dados.csv")
df
# Out:
#       condominio  quartos  suites  vagas  area    bairro    preco       pm2
# 0            350        1     0.0    1.0    21  Botafogo   340000  16190.48
# 1            800        1     0.0    1.0    64  Botafogo   770000  12031.25
# 2            674        1     0.0    1.0    61  Botafogo   600000   9836.07
# 3            700        1     1.0    1.0    70  Botafogo   700000  10000.00
# 4            440        1     0.0    1.0    44  Botafogo   515000  11704.55
# 5            917        1     1.0    1.0    60  Botafogo   630000  10500.00
# 6            850        1     1.0    1.0    65  Botafogo   740000  11384.62
# 7            350        1     1.0    1.0    43  Botafogo   570000  13255.81
# 8            440        1     1.0    1.0    26  Botafogo   430000  16538.46
# 9            510        1     1.0    1.0    42  Botafogo   500000  11904.76
# 10           200        1     0.0    1.0    35  Botafogo   500000  14285.71
# ...

# %%
#Apagar coluna
df = df.drop('pm2', axis=1)

# %%
df.tail()
# Out:
#       condominio  quartos  suites  vagas  area  bairro    preco
# 1992        1080        3     1.0    1.0    80  Tijuca   680000
# 1993         750        3     0.0    1.0    82  Tijuca   650000
# 1994         700        3     1.0    1.0   100  Tijuca   629900
# 1995        1850        3     1.0    2.0   166  Tijuca  1600000
# 1996         800        3     1.0    1.0   107  Tijuca   540000

# %%
#Apaga valoes NaN
df.dropna(axis=0, how='all', inplace=True)

# %%
#Converter numeros float
